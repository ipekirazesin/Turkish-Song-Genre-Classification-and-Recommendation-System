# %% [markdown]
# # PROJECT NOTEBOOK PART 1
# #### THIS NOTEBOOK IS DEDICATED TO PREPARATION OF THE AUDIO SAMPLE DATASET AND WEBSCRAPING.
#
# ##### 1) Download Songs From Youtube. https://pypi.org/project/yt-dlp
# ##### 2) Take Sample From a song & Save For Acoustic Feature Extraction,  https://ffmpeg.org/
#                                           setx /m PATH "C:\ffmpeg\bin;%PATH%"
#                                           pip install -r requirements.txt
# ##### 3) Webscraping video_title, length , tags using BeautifulSoup https://www.crummy.com/software/BeautifulSoup/
# ##### 4) Use Regular Expressions to get Lists of Music Genres and sub-Genres from https://www.musicgenreslist.com/
# ##### 5) READ_EXCEL and Use Data as Input to Our Functions and Automate the Entire Process.

# %%
import os
import sys
from time import time
import yt_dlp
from pydub import AudioSegment
# FUNCTION #1
def song_download_split(web_link,destination,sample_name,t_sec, duration = 10):
    """
    Download and store 10 second audio sample from YOUTUBE link.

    Parameters
    ----------
    web_link : string
        The youtube link that we get the audio sample from.
    destination : string
        The destination which we will store the sample .wav file
            >>>> f"{str(os.getcwd())}\datasets\AUDIO\{destination}\{sample_name}.wav"  
    sample_name : string
        Name of the sample for future references.
    t_sec : int
        Timestamp in seconds which is the moment 10 second sample begins.
        
    duration : int
        In seconds, how long the sample is going to be.

    Returns
    -------
    True

    """
    web_link = check_for_http(web_link)
    options = {
      'format': 'bestaudio/best',
      'extractaudio' : True,    # only keep the audio
      'audioformat' : "wav",    # convert to wav
      'outtmpl': 'temp.wav',    # '%(id)s' == name the file the ID of the video
      'noplaylist' : True,      # only download single song, not playlist
    }
    with yt_dlp.YoutubeDL(options) as ydl:
        ydl.download([web_link])
        
    t1 = t_sec * 1000 #Works in milliseconds
    t2 = (t_sec +duration)* 1000
    AudioSegment.converter = r"ffmpeg/bin/ffmpeg.exe" #r"C:\ffmpeg\bin\ffmpeg.exe"
    newAudio = AudioSegment.from_file(r'temp.wav')
    newAudio = newAudio[t1:t2]
    
    sample_name = "".join(i for i in sample_name if i not in "\/:*?<>|") # DROP ILLEGAL CHARS FOR FILE NAMING
    newAudio.export(f"{str(os.getcwd())}\\datasets\\AUDIO\\{destination}\\{sample_name}.wav", format="wav")
    os.remove(r'temp.wav')
    return f"Downloaded:{destination}\\{sample_name}.wav"

# EXTRA FUNCTIONS
def check_for_http(url):
    if url[0:8] == "https://":
        new_url = url
    else:
        new_url = r"https://" + url
    return new_url

# Disable / enable prints to keep the output clean
temp_stdout = None
# Disable
def disablePrint():
    global temp_stdout
    temp_stdout = sys.stdout
    sys.stdout = open(os.devnull, 'w')
def enablePrint():
    global temp_stdout
    sys.stdout = temp_stdout

# %%
# TESTING OUR FUNCTION
web_link = "https://www.youtube.com/watch?v=ySk8BaXiHv0"
destination = r'Piano Sample'
sample_name = "piano d3"
t_sec = 16
duration = 10

start_t =time()
output_msg = song_download_split(web_link, destination, sample_name, t_sec,duration)

print(f"{output_msg}\nTime taken : {(time() - start_t):.3f} seconds")
# Out:
# [youtube] ySk8BaXiHv0: Downloading webpage
# [youtube] ySk8BaXiHv0: Downloading android player API JSON
# [youtube] ySk8BaXiHv0: Downloading MPD manifest
# [youtube] ySk8BaXiHv0: Downloading MPD manifest
# [info] ySk8BaXiHv0: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 549.49KiB in 00:00
# Downloaded:Piano Sample\piano d3.wav
# Time taken : 3.602 seconds

# %% [markdown]
# ### WEBSCRAPING FOR GENRE & SUBGENRE NAMES
# ##### Obtaining the genre names from https://www.musicgenreslist.com/
# ##### Since bottom two cells will store the scraped data, we don't have to run them again after the first time.
# ##### We also don't have to use html request and beautifulsoup, we may as well just go ahead and download the source & use regex.

# %%
import re
f = open('datasets/web_source.txt','r',encoding ='utf-8')
text=f.readlines()
text="".join(text)
genre_labels =re.findall(r'<li><a title="([^<]*) - Music Genre"',text) # regex to find string of any length between text and text
genre_labels =[s.upper() for s in genre_labels]
print("genre_labels =",f"{genre_labels}\n")
genre_labels= set(genre_labels)

comprehensive_subgenres = re.findall(r"<li>([^<]*)<\/li>",text)
comprehensive_subgenres =[s.upper() for s in comprehensive_subgenres]
comprehensive_subgenres = [re.sub(r'\([^()]*\)', '', s) for s in comprehensive_subgenres] #regex remove parantheses descriptors
comprehensive_subgenres = [s[:-1] if s[-1] == " " else s for s in comprehensive_subgenres] # remove last char if == " "
print("some_sub_genres = ",f"{comprehensive_subgenres[10:20]}\nNumber of sub_genres = {len(comprehensive_subgenres)}")
comprehensive_subgenres = set(comprehensive_subgenres)
# Out:
# genre_labels = ['ALTERNATIVE', 'ANIME', 'BLUES', "CHILDREN'S MUSIC", 'CLASSICAL', 'COMEDY', 'COUNTRY', 'DANCE', 'DISNEY', 'EASY LISTENING', 'ELECTRONIC', 'ENKA', 'FRENCH POP', 'GERMAN FOLK', 'GERMAN POP', 'FITNESS &AMP; WORKOUT', 'HIP-HOP/RAP', 'HOLIDAY', 'INDIE POP', 'INDIE POP', 'CHRISTIAN &AMP; GOSPEL', 'INSTRUMENTAL', 'J-POP', 'JAZZ', 'K-POP', 'KARAOKE', 'KAYOKYOKU', 'LATINO', 'NEW AGE', 'OPERA', 'POP', 'R&AMP;B/SOUL', 'REGGAE', 'ROCK', 'SINGER/SONGWRITER', 'SOUNDTRACK', 'SPOKEN WORD', 'VOCAL', 'WORLD']
#
# some_sub_genres =  ['GRUNGE', 'HARDCORE PUNK', 'HARD ROCK', 'INDIE ROCK', 'LO-FI', 'MUSIQUE CONCRÈTE', 'NEW WAVE', 'PROGRESSIVE ROCK', 'PUNK', 'SHOEGAZE']
# Number of sub_genres = 819

# %%
# Save the file for easy access in another project 
# We are also going to use pickle again when the ML model is trained.
import pickle
outfile = open(r"datasets/genre_set",'wb') #write binary
pickle.dump(genre_labels,outfile)
outfile.close()

outfile = open(r"datasets/subgenre_set",'wb')
pickle.dump(comprehensive_subgenres,outfile)
outfile.close()

# %% [markdown]
# # FUNCTIONS FOR WEBSCRAPING THE METADATA

# %%
from requests_html import AsyncHTMLSession 
from bs4 import BeautifulSoup as bs
import re
import asyncio
import nest_asyncio # we need nested async because jupyter notebook has its own event loop running
nest_asyncio.apply()

#FUNCTION #2 
filter_genre_labels = lambda song_tags : {tag for tag in song_tags if tag in genre_labels}

#FUNCTION #3
filter_sub_genre_labels = lambda song_tags : {tag for tag in song_tags if tag in comprehensive_subgenres}

#sub-FUNCTION  of #4
async def create_soup(video_url):
    # init an HTML Session
    asession = AsyncHTMLSession()
    # get the html content
    response = await asession.get(video_url)
    # create bs object to parse HTML
    soup = bs(response.html.html, "html.parser")
    #soup.find_all("meta")
    return soup

# FUNCTION #4
def get_youtube_data(video_url):
    """
    Parameters
    ----------
    video_url : string
        The youtube link that we scrape the data from.
        
    Returns
    -------
    title : string
        Title of the video.
        
    tags : set
        Every tag of the video in uppercase.(additionally splits and adds multiple word tags.)
        
    duration_in_seconds : int
        Duration of the video calculated from meta data.
    """
    video_url = check_for_http(video_url)
    soup = asyncio.run(create_soup(video_url))
    
    # GETTING THE INFORMATION WE NEED
    title = soup.find("meta", itemprop="name")["content"]
    
    # TAGS
    tags =[meta.attrs.get("content") for meta in soup.find_all("meta", {"property": "og:video:tag"})]
    for item in tags: # IF A TAG CONSISTS OF MULTIPLE WORDS, SPLIT AND ADD THEM AS NEW TAGS 
        item= item.split()
        if len(item) > 1:
            tags += item
    tags= {tag.upper() for tag in tags}
    
    # DURATION
    # duration is stored in a weird string
    duration_string = soup.find("meta",itemprop = "duration")["content"]
    list_dur= re.findall("\\d+",duration_string) #regex to find decimals in string  1,23,33
    
    coefs=[1,60,3600] # second,minute,hour >> in seconds 
    duration_in_seconds = 0
    for item,second in zip(list_dur[::-1],coefs[0:len(list_dur)]):
        duration_in_seconds += int(item)*second
        
    return (title, tags, duration_in_seconds)  #P4M43ST

# %%
# Testing our functions
title, tags, length =  get_youtube_data("https://www.youtube.com/watch?v=tKi9Z-f6qX4")
print(filter_genre_labels(tags))
print(filter_sub_genre_labels(tags))
print(F"LENGTH IN SECONDS: {length}")
print(title)
# Out:
# {'DANCE', 'POP', 'ELECTRONIC'}
# {'MINIMAL', 'DISCO', 'PROGRESSIVE', 'ELECTRONIC DANCE MUSIC'}
# LENGTH IN SECONDS: 637
# deadmau5 - Strobe

# %% [markdown]
# ### ALL OF OUR FUNCTIONS APPLIED TO THE EXCEL TABLE IN ONE LOOP

# %%
import pandas as pd
excel = pd.read_excel("datasets/songs_urls.xlsx")
excel.columns = excel.iloc[0]
excel = excel[1:]
excel=excel.dropna()


to_download = excel
#to_download = excel[138:]
#to_download =excel.iloc[-16:]
#to_download = excel[excel["Genre"] == "Turkish Rap"]
print(excel.Genre.value_counts())
# Out:
# Turkish Pop                99
# Turkish Rock               95
# Turkish Slow               80
# Turkish Classical Music    62
# Turkish Folk Music         61
# Turkish Rap                51
# Piano Sample                1
# Name: Genre, dtype: int64

# %%
start = time()
# FOR EVERY COLUMN VALUE IN A ROW
for idx,row in to_download.iterrows():
    #print("----------------------------------")
    name, url, s, genre = row.T.to_list()         # unpack the values in a row
    title, tags, length =  get_youtube_data(url)  #4
    title = re.sub('[^\w_.)( -]', '', title)
    
    songs = os.listdir(str(os.getcwd()) + f"/datasets/AUDIO/{genre}")
    if f'{title}.wav' in songs:
        song_download_split(url, genre , title+'2', s) #1
    else:
        song_download_split(url, genre , title, s) # we dont use more than 2 sample from one song so this logic is enough
    print(idx)
    print(title)
    #print(length)
    #print("--TAGS--")
    #print(filter_genre_labels(tags))               #2
    #print(filter_sub_genre_labels(tags))           #3
    
print(f"--------------------------------\nIt took : {time()-start:.2f} seconds to download & get info about {len(to_download)} songs")
# Out:
# [youtube] 12zcvCdtp4Q: Downloading webpage
# [youtube] 12zcvCdtp4Q: Downloading android player API JSON
# [info] 12zcvCdtp4Q: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.85MiB in 00:01
# 1
# Leifur James - Mumma Dont Tell
# [youtube] HGC1cprNels: Downloading webpage
# [youtube] HGC1cprNels: Downloading android player API JSON
# [info] HGC1cprNels: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.77MiB in 00:00
# 2
# Ece Mumay - Vanilya
# [youtube] J9DvDxM_ur8: Downloading webpage
# [youtube] J9DvDxM_ur8: Downloading android player API JSON
# [info] J9DvDxM_ur8: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.57MiB in 00:00
# 3
# Demet Akalın - Bensiz Olsun
# [youtube] BebQwqnk0hM: Downloading webpage
# [youtube] BebQwqnk0hM: Downloading android player API JSON
# [info] BebQwqnk0hM: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.72MiB in 00:00
# 4
# Mustafa Ceceli  Nigar Muharrem- Salıncak
# [youtube] F7q6Ke4us1g: Downloading webpage
# [youtube] F7q6Ke4us1g: Downloading android player API JSON
# [info] F7q6Ke4us1g: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.37MiB in 00:00
# 5
# Irmak Arıcı - Asık Suratım
# [youtube] fZsUFpB3LzU: Downloading webpage
# [youtube] fZsUFpB3LzU: Downloading android player API JSON
# [info] fZsUFpB3LzU: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.77MiB in 00:00
# 6
# Reynmen ft. Zeynep Bastık - Yalan ( Official Video )
# [youtube] ZacERVAzPbw: Downloading webpage
# [youtube] ZacERVAzPbw: Downloading android player API JSON
# [info] ZacERVAzPbw: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.48MiB in 00:00
# 7
# Hande Yener - Sahte (Official Video)
# [youtube] qCOBzc29Bec: Downloading webpage
# [youtube] qCOBzc29Bec: Downloading android player API JSON
# [info] qCOBzc29Bec: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.75MiB in 00:00
# 8
# Merve Özbey - Yerle Yeksan
# [youtube] R6gSMSYKhKU: Downloading webpage
# [youtube] R6gSMSYKhKU: Downloading android player API JSON
# [info] R6gSMSYKhKU: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.76MiB in 00:01
# 9
# TARKAN  Geççek
# [youtube] Snof0wWI1GU: Downloading webpage
# [youtube] Snof0wWI1GU: Downloading android player API JSON
# [info] Snof0wWI1GU: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.04MiB in 00:01
# 10
# Melek Mosso - Hayatım Kaymış
# [youtube] hv-GXvl9RFI: Downloading webpage
# [youtube] hv-GXvl9RFI: Downloading android player API JSON
# [info] hv-GXvl9RFI: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.72MiB in 00:00
# 11
# Buray - Ask Yeniden (Yeni Türkü Zamansız)
# [youtube] NdtzZYxMcKA: Downloading webpage
# [youtube] NdtzZYxMcKA: Downloading android player API JSON
# [info] NdtzZYxMcKA: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.80MiB in 00:00
# 12
# Ziynet Sali - Kalbim Tatilde
# [youtube] vKROtqoWm5E: Downloading webpage
# [youtube] vKROtqoWm5E: Downloading android player API JSON
# [info] vKROtqoWm5E: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.34MiB in 00:01
# 13
# Merve Özbey - Kendine Dünya ( Official Video )
# [youtube] PoXja0ntGXw: Downloading webpage
# [youtube] PoXja0ntGXw: Downloading android player API JSON
# [info] PoXja0ntGXw: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.13MiB in 00:00
# 14
# Kurtuluş Kuş  Burak Bulut - Hasat
# [youtube] cOewK9n9WIM: Downloading webpage
# [youtube] cOewK9n9WIM: Downloading android player API JSON
# [info] cOewK9n9WIM: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.94MiB in 00:00
# 15
# Ece Mumay - Peri
# [youtube] Ac449ngA8lc: Downloading webpage
# [youtube] Ac449ngA8lc: Downloading android player API JSON
# [info] Ac449ngA8lc: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.69MiB in 00:00
# 16
# Alper Atakan  Hande Ünsal - Ah Anlatsam
# [youtube] _x3G9SD6wRQ: Downloading webpage
# [youtube] _x3G9SD6wRQ: Downloading android player API JSON
# [info] _x3G9SD6wRQ: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.69MiB in 00:00
# 17
# Derya Uluğ - Hadi Çal
# [youtube] NPUTdqYUa9A: Downloading webpage
# [youtube] NPUTdqYUa9A: Downloading android player API JSON
# [info] NPUTdqYUa9A: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.70MiB in 00:01
# 18
# Edis - Martılar (Official Video)
# [youtube] o9oQOqe3vqc: Downloading webpage
# [youtube] o9oQOqe3vqc: Downloading android player API JSON
# [info] o9oQOqe3vqc: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.11MiB in 00:00
# 19
# Edis - Arıyorum (Official Video)
# [youtube] wdoD2k3EqG0: Downloading webpage
# [youtube] wdoD2k3EqG0: Downloading android player API JSON
# [info] wdoD2k3EqG0: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.10MiB in 00:00
# 20
# Eypio  Arem Ozguc  Arman Aydin - Yan
# [youtube] psYBqXsJjKY: Downloading webpage
# [youtube] psYBqXsJjKY: Downloading android player API JSON
# [info] psYBqXsJjKY: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.80MiB in 00:01
# 21
# Tuğba Yurt - Yas
# [youtube] nhCoWU7_KvY: Downloading webpage
# [youtube] nhCoWU7_KvY: Downloading android player API JSON
# [info] nhCoWU7_KvY: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.05MiB in 00:00
# 22
# Ece Seçkin - Yastık
# [youtube] -li9BdpIK_s: Downloading webpage
# [youtube] -li9BdpIK_s: Downloading android player API JSON
# [info] -li9BdpIK_s: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.59MiB in 00:00
# 23
# Zeynep Bastık - Marlon Brando (Official Video)
# [youtube] 26xNHZzGJZI: Downloading webpage
# [youtube] 26xNHZzGJZI: Downloading android player API JSON
# [info] 26xNHZzGJZI: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.47MiB in 00:00
# 24
# Hadise - Hay Hay
# [youtube] Ck63ZX-QO_k: Downloading webpage
# [youtube] Ck63ZX-QO_k: Downloading android player API JSON
# [info] Ck63ZX-QO_k: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.77MiB in 00:00
# 25
# Derya Uluğ - Kanunlar Gibi
# [youtube] sJndOylFXt0: Downloading webpage
# [youtube] sJndOylFXt0: Downloading android player API JSON
# [info] sJndOylFXt0: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.47MiB in 00:00
# 26
# Alper Atakan  İrem Derici - Affeder mi Aşk Bizi
# [youtube] mc0d152UkNY: Downloading webpage
# [youtube] mc0d152UkNY: Downloading android player API JSON
# [info] mc0d152UkNY: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.28MiB in 00:00
# 27
# Oğuzhan Koç Arem Ozguc Arman Aydin - Yoksa Yasak (Official Video)
# [youtube] bbflWvhBIBU: Downloading webpage
# [youtube] bbflWvhBIBU: Downloading android player API JSON
# [info] bbflWvhBIBU: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.22MiB in 00:00
# 28
# Ziynet Sali - Efkarım Var
# [youtube] mSLtfJdx7k4: Downloading webpage
# [youtube] mSLtfJdx7k4: Downloading android player API JSON
# [info] mSLtfJdx7k4: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.09MiB in 00:00
# 29
# Yalın - Yaz Gülü aşklişelerigülaşka
# [youtube] SV9-9RvHsjY: Downloading webpage
# [youtube] SV9-9RvHsjY: Downloading android player API JSON
# [info] SV9-9RvHsjY: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.54MiB in 00:00
# 30
# Gülşen  Edis - Nirvana
# [youtube] QNoC_mVojhc: Downloading webpage
# [youtube] QNoC_mVojhc: Downloading android player API JSON
# [info] QNoC_mVojhc: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.05MiB in 00:01
# 31
# TARKAN - Öp
# [youtube] Jp-a6saWIUg: Downloading webpage
# [youtube] Jp-a6saWIUg: Downloading android player API JSON
# [info] Jp-a6saWIUg: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.09MiB in 00:00
# 32
# Demet Akalın - Bi Daha Bi Daha
# [youtube] PPWl1FK2BRQ: Downloading webpage
# [youtube] PPWl1FK2BRQ: Downloading android player API JSON
# [info] PPWl1FK2BRQ: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.23MiB in 00:00
# 33
# Çağla - Saz mı Caz mı
# [youtube] OgJ8GnXsXis: Downloading webpage
# [youtube] OgJ8GnXsXis: Downloading android player API JSON
# [info] OgJ8GnXsXis: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.30MiB in 00:00
# 34
# Kurtuluş Kuş  Burak Bulut - Baba Yak
# [youtube] 6U5ku3d1Gho: Downloading webpage
# [youtube] 6U5ku3d1Gho: Downloading android player API JSON
# [info] 6U5ku3d1Gho: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.64MiB in 00:00
# 35
# Cem Belevi - Melekti Sanki
# [youtube] gRdaIqQM-Js: Downloading webpage
# [youtube] gRdaIqQM-Js: Downloading android player API JSON
# [info] gRdaIqQM-Js: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.18MiB in 00:00
# 36
# Simge - Miş Miş
# [youtube] yk0MAn9WU_0: Downloading webpage
# [youtube] yk0MAn9WU_0: Downloading android player API JSON
# [info] yk0MAn9WU_0: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.33MiB in 00:00
# 37
# Zeynep Bastık - Her Mevsim Yazım (Official Video)
# [youtube] t4UdbmfIFAc: Downloading webpage
# [youtube] t4UdbmfIFAc: Downloading android player API JSON
# [info] t4UdbmfIFAc: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.89MiB in 00:01
# 38
# Gülşen feat. Murat Boz - İltimas
# [youtube] dO6Uj59sDjU: Downloading webpage
# [youtube] dO6Uj59sDjU: Downloading android player API JSON
# [info] dO6Uj59sDjU: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.44MiB in 00:00
# 39
# Eline Düştüm
# [youtube] JwV1gGjK9vY: Downloading webpage
# [youtube] JwV1gGjK9vY: Downloading android player API JSON
# [info] JwV1gGjK9vY: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.15MiB in 00:00
# 40
# Gülşen - Acısı Bile Bal (Beni Durdursan Mı) (08)
# [youtube] SwxLiuq4b2A: Downloading webpage
# [youtube] SwxLiuq4b2A: Downloading android player API JSON
# [info] SwxLiuq4b2A: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.85MiB in 00:01
# 41
# Ozan Doğulu feat. Demet Akalın - Kulüp
# [youtube] C4dTdlfI4mE: Downloading webpage
# [youtube] C4dTdlfI4mE: Downloading android player API JSON
# [info] C4dTdlfI4mE: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.04MiB in 00:00
# 42
# Erdem Kınay  Ft. Merve Özbey - Helal Ettim ( Official Video )
# [youtube] CwR3chrDskY: Downloading webpage
# [youtube] CwR3chrDskY: Downloading android player API JSON
# [info] CwR3chrDskY: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.46MiB in 00:00
# 43
# Murat Boz - Adını Bilen Yazsın
# [youtube] fZYZPANBF6g: Downloading webpage
# [youtube] fZYZPANBF6g: Downloading android player API JSON
# [info] fZYZPANBF6g: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 5.11MiB in 00:01
# 44
# maNga - Cevapsiz Sorular
# [youtube] qgjLKRWB6Y8: Downloading webpage
# [youtube] qgjLKRWB6Y8: Downloading android player API JSON
# [info] qgjLKRWB6Y8: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.00MiB in 00:00
# 45
# GECE - Ben Oldum
# [youtube] d2gVw7mHdc0: Downloading webpage
# [youtube] d2gVw7mHdc0: Downloading android player API JSON
# [info] d2gVw7mHdc0: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.31MiB in 00:01
# 46
# GECE - Gamsiz
# [youtube] yCmuNhYogAs: Downloading webpage
# [youtube] yCmuNhYogAs: Downloading android player API JSON
# [info] yCmuNhYogAs: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.11MiB in 00:01
# 47
# Demir Demirkan - Zaferlerim (2004 Istanbul)
# [youtube] l9i-0AX5sdo: Downloading webpage
# [youtube] l9i-0AX5sdo: Downloading android player API JSON
# [info] l9i-0AX5sdo: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.32MiB in 00:01
# 48
# Seksendört - Kendime Yalan Söyledim ( Official Video )
# [youtube] qh21dQ3N7Aw: Downloading webpage
# [youtube] qh21dQ3N7Aw: Downloading android player API JSON
# [youtube] qh21dQ3N7Aw: Downloading MPD manifest
# [youtube] qh21dQ3N7Aw: Downloading MPD manifest
# [info] qh21dQ3N7Aw: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.46MiB in 00:01
# 49
# Keçi K. - Böcek
# [youtube] uQziTZhkmDI: Downloading webpage
# [youtube] uQziTZhkmDI: Downloading android player API JSON
# [info] uQziTZhkmDI: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.41MiB in 00:01
# 50
# mor ve ötesi - Oyunbozan  (Official Video)
# [youtube] bZZG_8rN4As: Downloading webpage
# [youtube] bZZG_8rN4As: Downloading android player API JSON
# [info] bZZG_8rN4As: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.78MiB in 00:01
# 51
# En Güzel Yerinde Evin
# [youtube] lJXhxvJBeX0: Downloading webpage
# [youtube] lJXhxvJBeX0: Downloading android player API JSON
# [info] lJXhxvJBeX0: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.07MiB in 00:01
# 52
# Olduramadım
# [youtube] cYuGJ2wQNxA: Downloading webpage
# [youtube] cYuGJ2wQNxA: Downloading android player API JSON
# [info] cYuGJ2wQNxA: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.09MiB in 00:01
# 53
# Gemiler
# [youtube] lh4lMzVcM8A: Downloading webpage
# [youtube] lh4lMzVcM8A: Downloading android player API JSON
# [info] lh4lMzVcM8A: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.84MiB in 00:00
# 54
# Teoman - Paramparça
# [youtube] P_hLDSDv0iU: Downloading webpage
# [youtube] P_hLDSDv0iU: Downloading android player API JSON
# [info] P_hLDSDv0iU: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.65MiB in 00:01
# 55
# Öyle Dertli
# [youtube] 4ZPuGxdDf_4: Downloading webpage
# [youtube] 4ZPuGxdDf_4: Downloading android player API JSON
# [info] 4ZPuGxdDf_4: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.60MiB in 00:00
# 56
# Duman - Dibine Kadar
# [youtube] Y5XwoJRSpjQ: Downloading webpage
# [youtube] Y5XwoJRSpjQ: Downloading android player API JSON
# [info] Y5XwoJRSpjQ: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.65MiB in 00:01
# 57
# Bir Kadın Çizeceksin
# [youtube] pIVG3mDL9RI: Downloading webpage
# [youtube] pIVG3mDL9RI: Downloading android player API JSON
# [info] pIVG3mDL9RI: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.00MiB in 00:01
# 58
# maNga - Dunyanin Sonuna Dogmusum
# [youtube] VeOtv894ls8: Downloading webpage
# [youtube] VeOtv894ls8: Downloading android player API JSON
# [info] VeOtv894ls8: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.86MiB in 00:00
# 59
# mor ve ötesi - Deli (Official Video)
# [youtube] Lw4unI3tVNQ: Downloading webpage
# [youtube] Lw4unI3tVNQ: Downloading android player API JSON
# [info] Lw4unI3tVNQ: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.82MiB in 00:00
# 60
# mor ve ötesi - Cambaz (Official Video)
# [youtube] 6qRQm2QXDAs: Downloading webpage
# [youtube] 6qRQm2QXDAs: Downloading android player API JSON
# [info] 6qRQm2QXDAs: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.91MiB in 00:00
# 61
# maNga - Beni Benimle Birak
# [youtube] hxaCtfmi6po: Downloading webpage
# [youtube] hxaCtfmi6po: Downloading android player API JSON
# [info] hxaCtfmi6po: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.75MiB in 00:01
# 62
# Şebnem Ferah - Çakıl Taşları
# [youtube] CtVoY3eOjrM: Downloading webpage
# [youtube] CtVoY3eOjrM: Downloading android player API JSON
# [info] CtVoY3eOjrM: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.20MiB in 00:01
# 63
# Sebnem Ferah - Bu Ask Fazla Sana
# [youtube] CdbeLMKTG6Q: Downloading webpage
# [youtube] CdbeLMKTG6Q: Downloading android player API JSON
# [info] CdbeLMKTG6Q: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.89MiB in 00:01
# 64
# Sigara
# [youtube] R_wqOrPpui0: Downloading webpage
# [youtube] R_wqOrPpui0: Downloading android player API JSON
# [info] R_wqOrPpui0: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 5.55MiB in 00:02
# 65
# Şebnem Ferah - Can Kırıkları
# [youtube] etJqjyPi6Bw: Downloading webpage
# [youtube] etJqjyPi6Bw: Downloading android player API JSON
# [info] etJqjyPi6Bw: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.60MiB in 00:01
# 66
# Bir
# [youtube] 7XU_NIUOUrg: Downloading webpage
# [youtube] 7XU_NIUOUrg: Downloading android player API JSON
# [info] 7XU_NIUOUrg: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.66MiB in 00:01
# 67
# Pentagram - Gecmisin Yuku
# [youtube] tm-Uk2o1Foo: Downloading webpage
# [youtube] tm-Uk2o1Foo: Downloading android player API JSON
# [info] tm-Uk2o1Foo: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.46MiB in 00:00
# 68
# Öpücük
# [youtube] rd4-JyFnmQk: Downloading webpage
# [youtube] rd4-JyFnmQk: Downloading android player API JSON
# [info] rd4-JyFnmQk: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.17MiB in 00:00
# 69
# Athena - Arsız Gönül (GQ Men of the Year 2016)
# [youtube] 5QpW1FofT2w: Downloading webpage
# [youtube] 5QpW1FofT2w: Downloading android player API JSON
# [info] 5QpW1FofT2w: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.96MiB in 00:00
# 70
# Kafama Göre
# [youtube] mVE4Up0I7IU: Downloading webpage
# [youtube] mVE4Up0I7IU: Downloading android player API JSON
# [info] mVE4Up0I7IU: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.63MiB in 00:00
# 71
# PENTAGRAM - Şeytan Bunun Neresinde
# [youtube] MfZ4yw3gdBg: Downloading webpage
# [youtube] MfZ4yw3gdBg: Downloading android player API JSON
# [info] MfZ4yw3gdBg: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.99MiB in 00:00
# 72
# Özlem Tekin - Dağları Deldim
# [youtube] ZMaHn82YOlw: Downloading webpage
# [youtube] ZMaHn82YOlw: Downloading android player API JSON
# [info] ZMaHn82YOlw: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.77MiB in 00:01
# 73
# Özlem Tekin - Sen Anla
# [youtube:tab] Downloading just video lTjBm4F54-U because of --no-playlist
# [youtube] lTjBm4F54-U: Downloading webpage
# [youtube] lTjBm4F54-U: Downloading android player API JSON
# [info] lTjBm4F54-U: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.34MiB in 00:00
# 74
# Kaç canım kalmış - Kafamı hissetmiyorum
# [youtube] sRc06D93_sc: Downloading webpage
# [youtube] sRc06D93_sc: Downloading android player API JSON
# [info] sRc06D93_sc: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 5.78MiB in 00:02
# 75
# Yavuz Çetin Yasamak Istemem
# [youtube] N3jWKHxqUUw: Downloading webpage
# [youtube] N3jWKHxqUUw: Downloading android player API JSON
# [info] N3jWKHxqUUw: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 7.51MiB in 00:03
# 76
# Yavuz Çetin - Benimle Uçmak İster Misin (Official Audio)
# [youtube] 6ID8GZ34Im0: Downloading webpage
# [youtube] 6ID8GZ34Im0: Downloading android player API JSON
# [info] 6ID8GZ34Im0: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.50MiB in 00:01
# 77
# Yavuz Çetin - Kurtar Beni (Official Audio)
# [youtube] qh21dQ3N7Aw: Downloading webpage
# [youtube] qh21dQ3N7Aw: Downloading android player API JSON
# [youtube] qh21dQ3N7Aw: Downloading MPD manifest
# [youtube] qh21dQ3N7Aw: Downloading MPD manifest
# [info] qh21dQ3N7Aw: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.46MiB in 00:01
# 78
# Keçi K. - Böcek
# [youtube] Kj1kjnJXxBo: Downloading webpage
# [youtube] Kj1kjnJXxBo: Downloading android player API JSON
# [info] Kj1kjnJXxBo: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.32MiB in 00:00
# 79
# Pinhâni - Kimse Görmesin Seni
# [youtube] Rck7xMNMK2U: Downloading webpage
# [youtube] Rck7xMNMK2U: Downloading android player API JSON
# [info] Rck7xMNMK2U: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.55MiB in 00:00
# 80
# Yüzyüzeyken Konuşuruz - Gençliğimi Geri Ver
# [youtube] cApyFCgSsiQ: Downloading webpage
# [youtube] cApyFCgSsiQ: Downloading android player API JSON
# [info] cApyFCgSsiQ: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.06MiB in 00:00
# 81
# Demet Akalın - Nazar
# [youtube] -XXlWr4Ml4E: Downloading webpage
# [youtube] -XXlWr4Ml4E: Downloading android player API JSON
# [info] -XXlWr4Ml4E: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.39MiB in 00:00
# 82
# Aşktan Öte
# [youtube] 2jSMXR71d6c: Downloading webpage
# [youtube] 2jSMXR71d6c: Downloading android player API JSON
# [info] 2jSMXR71d6c: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.50MiB in 00:01
# 83
# Barış Akarsu - Islak Islak
# [youtube] 9tCUJFd8ME4: Downloading webpage
# [youtube] 9tCUJFd8ME4: Downloading android player API JSON
# [info] 9tCUJFd8ME4: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.16MiB in 00:00
# 84
# Umut Kaya - Mevsimler Geçerken
# [youtube] JP4kValjHmw: Downloading webpage
# [youtube] JP4kValjHmw: Downloading android player API JSON
# [info] JP4kValjHmw: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.64MiB in 00:01
# 85
# Gripin - Sensiz Istanbula Düsmanim
# [youtube] FBpq9qE02kk: Downloading webpage
# [youtube] FBpq9qE02kk: Downloading android player API JSON
# [info] FBpq9qE02kk: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.97MiB in 00:00
# 86
# Aylin Aslım - Ben Kalender Meşrebim
# [youtube] G2nXKQ-Zz2s: Downloading webpage
# [youtube] G2nXKQ-Zz2s: Downloading android player API JSON
# [info] G2nXKQ-Zz2s: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.90MiB in 00:03
# 87
# Şebnem Ferah  Hayko Cepkin  Badem  TNK  Aylin Aslım - Özgürce Yaşa
# [youtube] _fw5GJdAbLY: Downloading webpage
# [youtube] _fw5GJdAbLY: Downloading android player API JSON
# [info] _fw5GJdAbLY: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.56MiB in 00:01
# 88
# Pamela - istanbul
# [youtube] l0VK260mIos: Downloading webpage
# [youtube] l0VK260mIos: Downloading android player API JSON
# [info] l0VK260mIos: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 5.51MiB in 00:02
# 89
# Kıraç - Senden Başka (Official Video)
# [youtube] y74untir_dI: Downloading webpage
# [youtube] y74untir_dI: Downloading android player API JSON
# [info] y74untir_dI: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.60MiB in 00:01
# 90
# Ogün Sanlısoy - Geri Dönemem
# [youtube] gqOZIhgEqac: Downloading webpage
# [youtube] gqOZIhgEqac: Downloading android player API JSON
# [info] gqOZIhgEqac: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.94MiB in 00:01
# 91
# Ogün Sanlisoy - Bilmece
# [youtube] RTj7_HMCBeI: Downloading webpage
# [youtube] RTj7_HMCBeI: Downloading android player API JSON
# [info] RTj7_HMCBeI: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.48MiB in 00:00
# 92
# Hayko Cepkin - Bertaraf Et
# [youtube] bsyMjGrcG7U: Downloading webpage
# [youtube] bsyMjGrcG7U: Downloading android player API JSON
# [info] bsyMjGrcG7U: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.92MiB in 00:00
# 93
# Namus Belası
# [youtube] Pwqp-lZhwho: Downloading webpage
# [youtube] Pwqp-lZhwho: Downloading android player API JSON
# [info] Pwqp-lZhwho: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.32MiB in 00:00
# 94
# Gökyüzünde Yalnız Gezen Yıldızlar
# [youtube] Pwqp-lZhwho: Downloading webpage
# [youtube] Pwqp-lZhwho: Downloading android player API JSON
# [info] Pwqp-lZhwho: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.32MiB in 00:00
# 95
# Gökyüzünde Yalnız Gezen Yıldızlar
# [youtube] Oh9es4Eh2XM: Downloading webpage
# [youtube] Oh9es4Eh2XM: Downloading android player API JSON
# [info] Oh9es4Eh2XM: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.48MiB in 00:00
# 96
# emel sayın-duydumki unutmuşsun gözlerimin rengini.
# [youtube] 5LfPuO3FSeQ: Downloading webpage
# [youtube] 5LfPuO3FSeQ: Downloading android player API JSON
# [info] 5LfPuO3FSeQ: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 5.79MiB in 00:02
# 97
# Müzeyyen Senar - Elbet Bir Gün Buluşacağız (1980)
# [youtube] 8BW-OkHv8qQ: Downloading webpage
# [youtube] 8BW-OkHv8qQ: Downloading android player API JSON
# [info] 8BW-OkHv8qQ: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.66MiB in 00:01
# 98
# Adnan Şenses - Kavuşamadık (Official Video)
# [youtube] HDIBU25z6X4: Downloading webpage
# [youtube] HDIBU25z6X4: Downloading android player API JSON
# [info] HDIBU25z6X4: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.68MiB in 00:00
# 99
# Müzeyyen Senar - Kimseye Etmem Şikayet (1985-1990)
# [youtube] 8BILYz6PRIk: Downloading webpage
# [youtube] 8BILYz6PRIk: Downloading android player API JSON
# [info] 8BILYz6PRIk: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 5.24MiB in 00:01
# 100
# Ah Bu Şarkıların Gözü Kör Olsun
# [youtube] 8XK_xinYBo8: Downloading webpage
# [youtube] 8XK_xinYBo8: Downloading android player API JSON
# [info] 8XK_xinYBo8: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 5.39MiB in 00:02
# 101
# Sami Özer - Demedim mi
# [youtube] cq_zb0qVKsA: Downloading webpage
# [youtube] cq_zb0qVKsA: Downloading android player API JSON
# [info] cq_zb0qVKsA: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.12MiB in 00:01
# 102
# Muazzez Abaci   Donulmez Aksamin Ufkundayiz
# [youtube] rLLJeoha1sI: Downloading webpage
# [youtube] rLLJeoha1sI: Downloading android player API JSON
# [info] rLLJeoha1sI: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 5.98MiB in 00:02
# 103
# Neşe Karaböcek - Sildim Seni Kalbimden  Kaset Kayıtları (1985)
# [youtube] nAbYM3cmvro: Downloading webpage
# [youtube] nAbYM3cmvro: Downloading android player API JSON
# [info] nAbYM3cmvro: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.79MiB in 00:01
# 104
# Gönül Akkor - Dost Bildiklerim
# [youtube] nAbYM3cmvro: Downloading webpage
# [youtube] nAbYM3cmvro: Downloading android player API JSON
# [info] nAbYM3cmvro: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.79MiB in 00:01
# 105
# Gönül Akkor - Dost Bildiklerim
# [youtube] kyVlI7BVokw: Downloading webpage
# [youtube] kyVlI7BVokw: Downloading android player API JSON
# [info] kyVlI7BVokw: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.73MiB in 00:01
# 106
# Ben Seni Unutmak İçin Sevmedim
# [youtube] uBLPMQ9QeDs: Downloading webpage
# [youtube] uBLPMQ9QeDs: Downloading android player API JSON
# [info] uBLPMQ9QeDs: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.63MiB in 00:01
# 107
# Neşe Karaböcek - Kıskanırım Seni Ben
# [youtube] L0AEocEq5yo: Downloading webpage
# [youtube] L0AEocEq5yo: Downloading android player API JSON
# [info] L0AEocEq5yo: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.00MiB in 00:00
# 108
# Muazzez Ersoy-Sevemez Kimse Seni
# [youtube] 1Cc-Vx5zTQM: Downloading webpage
# [youtube] 1Cc-Vx5zTQM: Downloading android player API JSON
# [info] 1Cc-Vx5zTQM: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.76MiB in 00:01
# 109
# Seni Sordum Yıldızlara
# [youtube] xf03yhnZ6D8: Downloading webpage
# [youtube] xf03yhnZ6D8: Downloading android player API JSON
# [info] xf03yhnZ6D8: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.13MiB in 00:01
# 110
# Behiye Aksoy - Benim İçin Öldün Artık (Official Audio)
# [youtube] 39h7nCMJK4U: Downloading webpage
# [youtube] 39h7nCMJK4U: Downloading android player API JSON
# [info] 39h7nCMJK4U: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.87MiB in 00:01
# 111
# Dert Bende
# [youtube] AbwFiFp_8lI: Downloading webpage
# [youtube] AbwFiFp_8lI: Downloading android player API JSON
# [info] AbwFiFp_8lI: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.29MiB in 00:00
# 112
# Gezdiğim Dikenli Aşk Yollarında
# [youtube] ib2b2FSU-BI: Downloading webpage
# [youtube] ib2b2FSU-BI: Downloading android player API JSON
# [info] ib2b2FSU-BI: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.53MiB in 00:00
# 113
# Gece Hikayeleri
# [youtube] tmrQXhwF0To: Downloading webpage
# [youtube] tmrQXhwF0To: Downloading android player API JSON
# [info] tmrQXhwF0To: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.75MiB in 00:01
# 114
# Yağmurlar - Anıl Piyancı  Perdenin Ardındakiler
# [youtube] WWfL94_E1a8: Downloading webpage
# [youtube] WWfL94_E1a8: Downloading android player API JSON
# [info] WWfL94_E1a8: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.78MiB in 00:00
# 115
# Murat Dalkılıç - Son Liman - (Official Video)
# [youtube] 3XU064zGweo: Downloading webpage
# [youtube] 3XU064zGweo: Downloading android player API JSON
# [info] 3XU064zGweo: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.41MiB in 00:00
# 116
# İndir
# [youtube] 7QTtOMn5aEI: Downloading webpage
# [youtube] 7QTtOMn5aEI: Downloading android player API JSON
# [info] 7QTtOMn5aEI: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.11MiB in 00:01
# 117
# Hayko Cepkin - Ölüyorum
# [youtube] RN-YBLC8TcA: Downloading webpage
# [youtube] RN-YBLC8TcA: Downloading android player API JSON
# [info] RN-YBLC8TcA: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.56MiB in 00:01
# 118
# MERVE ÖZBEY - YAŞ HİKAYESİ (Official Video)
# [youtube] yJpJCZYTL74: Downloading webpage
# [youtube] yJpJCZYTL74: Downloading android player API JSON
# [info] yJpJCZYTL74: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.17MiB in 00:00
# 119
# Aleyna Tilki - Sen Olsan Bari
# [youtube] TAX94fjXU2c: Downloading webpage
# [youtube] TAX94fjXU2c: Downloading android player API JSON
# [info] TAX94fjXU2c: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.57MiB in 00:00
# 120
# Ozan Çolakoğlu feat Gülşen - Seyre Dursun Aşk
# [youtube] Slpvba4ZTTs: Downloading webpage
# [youtube] Slpvba4ZTTs: Downloading android player API JSON
# [info] Slpvba4ZTTs: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.71MiB in 00:00
# 121
# Yıldızların Altında
# [youtube] 0YaceGlfblU: Downloading webpage
# [youtube] 0YaceGlfblU: Downloading android player API JSON
# [info] 0YaceGlfblU: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.60MiB in 00:01
# 122
# Yok Oyle Kararli Seyler - Gel Tamamla Akustikhane
# [youtube] 7QL29OLoD-Q: Downloading webpage
# [youtube] 7QL29OLoD-Q: Downloading android player API JSON
# [info] 7QL29OLoD-Q: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 9.43MiB in 00:04
# 123
# Siyah Beyaz
# [youtube] 7QL29OLoD-Q: Downloading webpage
# [youtube] 7QL29OLoD-Q: Downloading android player API JSON
# [info] 7QL29OLoD-Q: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 9.43MiB in 00:04
# 124
# Siyah Beyaz
# [youtube:tab] Downloading just video weKTwuxqop8 because of --no-playlist
# [youtube] weKTwuxqop8: Downloading webpage
# [youtube] weKTwuxqop8: Downloading android player API JSON
# [info] weKTwuxqop8: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.50MiB in 00:00
# 125
# Araftafaray
# [youtube] UiyxPIvB89Q: Downloading webpage
# [youtube] UiyxPIvB89Q: Downloading android player API JSON
# [info] UiyxPIvB89Q: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.39MiB in 00:00
# 126
# CEZA - Holocaust (Official Audio)
# [youtube] Tzi_nl0XKgk: Downloading webpage
# [youtube] Tzi_nl0XKgk: Downloading android player API JSON
# [info] Tzi_nl0XKgk: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.40MiB in 00:01
# 127
# CEZA - Yerli Plaka (Official Audio)
# [youtube] 3GiO2hfzbZY: Downloading webpage
# [youtube] 3GiO2hfzbZY: Downloading android player API JSON
# [info] 3GiO2hfzbZY: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.96MiB in 00:01
# 128
# CEZA - Med Cezir (Official Audio)
# [youtube] XKA-NfBDVyE: Downloading webpage
# [youtube] XKA-NfBDVyE: Downloading android player API JSON
# [info] XKA-NfBDVyE: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.43MiB in 00:00
# 129
# Sanıser - Gel (Official Video)
# [youtube] TmZNuNPHljA: Downloading webpage
# [youtube] TmZNuNPHljA: Downloading android player API JSON
# [info] TmZNuNPHljA: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.11MiB in 00:00
# 130
# Farazi V Kayra - Mevsim Olmayan Mekanlar V Unutulanlar feat. Karaçalı Vinyl Obscura
# [youtube] Fyb4QAZVVv0: Downloading webpage
# [youtube] Fyb4QAZVVv0: Downloading android player API JSON
# [info] Fyb4QAZVVv0: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.32MiB in 00:01
# 131
# 90BPM - Elimde Yalanlarla (feat. Ezhel) (Official Audio)
# [youtube] nj6bTJjclTI: Downloading webpage
# [youtube] nj6bTJjclTI: Downloading android player API JSON
# [info] nj6bTJjclTI: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 1.51MiB in 00:00
# 132
# Ağaçkakan - Entropi  Official Music Video
# [youtube] Xo6Yba9LZXU: Downloading webpage
# [youtube] Xo6Yba9LZXU: Downloading android player API JSON
# [info] Xo6Yba9LZXU: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.58MiB in 00:00
# 133
# Gülşen - Yatcaz Kalkcaz Ordayım
# [youtube] P-2gl0QUQUM: Downloading webpage
# [youtube] P-2gl0QUQUM: Downloading android player API JSON
# [info] P-2gl0QUQUM: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.03MiB in 00:00
# 134
# Murat Dalkılıç feat. Boygar - Leyla
# [youtube] TtmPYw3DY4g: Downloading webpage
# [youtube] TtmPYw3DY4g: Downloading android player API JSON
# [info] TtmPYw3DY4g: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.79MiB in 00:01
# 135
# Demet Akalın - İlahi Adalet
# [youtube] 82e-H4xTuIw: Downloading webpage
# [youtube] 82e-H4xTuIw: Downloading android player API JSON
# [info] 82e-H4xTuIw: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.95MiB in 00:00
# 136
# Bengü - Kuzum
# [youtube] F9FEomKKTwQ: Downloading webpage
# [youtube] F9FEomKKTwQ: Downloading android player API JSON
# [info] F9FEomKKTwQ: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.58MiB in 00:00
# 137
# MERVE ÖZBEY - TOPSUZ TÜFEKSİZ (Official Video)
# [youtube] 6GelvRXUVkE: Downloading webpage
# [youtube] 6GelvRXUVkE: Downloading android player API JSON
# [info] 6GelvRXUVkE: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.21MiB in 00:00
# 138
# Bengü - Feveran
# [youtube] AOfj9fUeudw: Downloading webpage
# [youtube] AOfj9fUeudw: Downloading android player API JSON
# [info] AOfj9fUeudw: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.67MiB in 00:01
# 139
# Demet Akalın - Pırlanta
# [youtube] OahiYiVLg34: Downloading webpage
# [youtube] OahiYiVLg34: Downloading android player API JSON
# [info] OahiYiVLg34: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.69MiB in 00:01
# 140
# Demet Akalın  - Çanta
# [youtube] YqNqw4o-JBY: Downloading webpage
# [youtube] YqNqw4o-JBY: Downloading android player API JSON
# [info] YqNqw4o-JBY: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.23MiB in 00:00
# 141
# Emrah Karaduman feat. Murat Dalkılıç - Kırk Yılda Bir Gibisin
# [youtube] Tb-zjsEqr1k: Downloading webpage
# [youtube] Tb-zjsEqr1k: Downloading android player API JSON
# [info] Tb-zjsEqr1k: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.04MiB in 00:00
# 142
# Tuğba Yurt - İnceden İnceden
# [youtube] kqDKnbiK5j0: Downloading webpage
# [youtube] kqDKnbiK5j0: Downloading android player API JSON
# [info] kqDKnbiK5j0: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.41MiB in 00:00
# 143
# Ozan Doğulu feat. Gülden  Bahadır Tatlıöz - Uzun Lafın Kısası
# [youtube] PEqL94bN2l0: Downloading webpage
# [youtube] PEqL94bN2l0: Downloading android player API JSON
# [info] PEqL94bN2l0: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.07MiB in 00:01
# 144
# Gülşen - Yurtta Aşk Cihanda Aşk
# [youtube] sprukwRl9ZQ: Downloading webpage
# [youtube] sprukwRl9ZQ: Downloading android player API JSON
# [info] sprukwRl9ZQ: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.29MiB in 00:00
# 145
# Hande Yener - Naber ( Official Video )
# [youtube] mCkcvwTbadE: Downloading webpage
# [youtube] mCkcvwTbadE: Downloading android player API JSON
# [info] mCkcvwTbadE: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.50MiB in 00:00
# 146
# Ziynet Sali - Deli Divanenim
# [youtube] sui9MKrDnQk: Downloading webpage
# [youtube] sui9MKrDnQk: Downloading android player API JSON
# [info] sui9MKrDnQk: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.49MiB in 00:00
# 147
# Hadise - Sıfır Tolerans
# [youtube] UDddZzNAv4Y: Downloading webpage
# [youtube] UDddZzNAv4Y: Downloading android player API JSON
# [info] UDddZzNAv4Y: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.20MiB in 00:00
# 148
# Hande Ünsal - Seni Sever miydim
# [youtube] ho-6xyNuyAA: Downloading webpage
# [youtube] ho-6xyNuyAA: Downloading android player API JSON
# [info] ho-6xyNuyAA: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.77MiB in 00:01
# 149
# TAN TAŞÇI - HATA ( OFFICIAL AUDIO )
# [youtube] qf3nystqFEw: Downloading webpage
# [youtube] qf3nystqFEw: Downloading android player API JSON
# [info] qf3nystqFEw: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.37MiB in 00:00
# 150
# Emre Kaya - Esaret
# [youtube] TDqL6_ni7e4: Downloading webpage
# [youtube] TDqL6_ni7e4: Downloading android player API JSON
# [info] TDqL6_ni7e4: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.34MiB in 00:00
# 151
# Gülşen - Irgalamaz Beni
# [youtube] QjRYopBRUIc: Downloading webpage
# [youtube] QjRYopBRUIc: Downloading android player API JSON
# [info] QjRYopBRUIc: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.81MiB in 00:01
# 152
# Murat Boz - Janti
# [youtube] hVRDtg2OEMU: Downloading webpage
# [youtube] hVRDtg2OEMU: Downloading android player API JSON
# [info] hVRDtg2OEMU: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.19MiB in 00:01
# 153
# Demet Akalın - Giderli Şarkılar
# [youtube] KOHvPg8B_Lo: Downloading webpage
# [youtube] KOHvPg8B_Lo: Downloading android player API JSON
# [info] KOHvPg8B_Lo: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.81MiB in 00:01
# 154
# Ayşe Hatun Önal - Katakulli
# [youtube] TFp0Y5jqcwQ: Downloading webpage
# [youtube] TFp0Y5jqcwQ: Downloading android player API JSON
# [info] TFp0Y5jqcwQ: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.24MiB in 00:00
# 155
# LUCIANO feat LIL ZEY - ELMAS
# [youtube] EoFybFg7SpE: Downloading webpage
# [youtube] EoFybFg7SpE: Downloading android player API JSON
# [info] EoFybFg7SpE: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 5.13MiB in 00:01
# 156
# XIR - Ne Sandın (Official Video)
# [youtube] XpjjnaR6q14: Downloading webpage
# [youtube] XpjjnaR6q14: Downloading android player API JSON
# [info] XpjjnaR6q14: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.33MiB in 00:00
# 157
# Khontkar - Geldiğim Yer (Geldiğim Yer Soundtrack)
# [youtube] quwybaIr5aA: Downloading webpage
# [youtube] quwybaIr5aA: Downloading android player API JSON
# [info] quwybaIr5aA: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.61MiB in 00:00
# 158
# Contra - Kibir
# [youtube] GH6MB7YH-Bg: Downloading webpage
# [youtube] GH6MB7YH-Bg: Downloading android player API JSON
# [info] GH6MB7YH-Bg: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.28MiB in 00:00
# 159
# Contra - Ölü
# [youtube] QsVBtWY6hJ4: Downloading webpage
# [youtube] QsVBtWY6hJ4: Downloading android player API JSON
# [info] QsVBtWY6hJ4: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.70MiB in 00:01
# 160
# Contra - Tehlikeli (Official Video)
# [youtube] QsVBtWY6hJ4: Downloading webpage
# [youtube] QsVBtWY6hJ4: Downloading android player API JSON
# [info] QsVBtWY6hJ4: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.70MiB in 00:01
# 161
# Contra - Tehlikeli (Official Video)
# [youtube] ZdvdymBbMbM: Downloading webpage
# [youtube] ZdvdymBbMbM: Downloading android player API JSON
# [info] ZdvdymBbMbM: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.00MiB in 00:00
# 162
# Contra - kıvılcım
# [youtube] SEvtTRZXCjQ: Downloading webpage
# [youtube] SEvtTRZXCjQ: Downloading android player API JSON
# [info] SEvtTRZXCjQ: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.18MiB in 00:00
# 163
# Murat Boz - Vazgeçmem
# [youtube] Fi15jicjMLc: Downloading webpage
# [youtube] Fi15jicjMLc: Downloading android player API JSON
# [info] Fi15jicjMLc: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.53MiB in 00:01
# 164
# Mavi Gri - Dünyanın En Güzel Kızı (Lyrics Video)
# [youtube] MDTECCzdOgI: Downloading webpage
# [youtube] MDTECCzdOgI: Downloading android player API JSON
# [info] MDTECCzdOgI: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.78MiB in 00:01
# 165
# Adamlar - Benden Bana
# [youtube] Y-S5PRyss-k: Downloading webpage
# [youtube] Y-S5PRyss-k: Downloading android player API JSON
# [info] Y-S5PRyss-k: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.24MiB in 00:00
# 166
# Lil Zey - Peygamber Sabrı feat. GOKO
# [youtube] 6tKEpeZ4P4o: Downloading webpage
# [youtube] 6tKEpeZ4P4o: Downloading android player API JSON
# [info] 6tKEpeZ4P4o: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.48MiB in 00:00
# 167
# Lil Zey - Vuslat
# [youtube] H90aHmaNlQE: Downloading webpage
# [youtube] H90aHmaNlQE: Downloading android player API JSON
# [info] H90aHmaNlQE: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.92MiB in 00:00
# 168
# Lil Zey - 1 gr eksik (Music Video)
# [youtube] GSSkSX_pR2w: Downloading webpage
# [youtube] GSSkSX_pR2w: Downloading android player API JSON
# [info] GSSkSX_pR2w: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.27MiB in 00:00
# 169
# KOKVL  Lil Zey - Otede Dur (Music Video)
# [youtube] RHUNgsbkEps: Downloading webpage
# [youtube] RHUNgsbkEps: Downloading android player API JSON
# [info] RHUNgsbkEps: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 5.19MiB in 00:01
# 170
# Lil Zey - Zor  Zor II (Music Video)
# [youtube] o-OPeZIELHE: Downloading webpage
# [youtube] o-OPeZIELHE: Downloading android player API JSON
# [info] o-OPeZIELHE: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.24MiB in 00:01
# 171
# Ezhel - Şehrimin  Tadı
# [youtube] sxVYkUVtih4: Downloading webpage
# [youtube] sxVYkUVtih4: Downloading android player API JSON
# [info] sxVYkUVtih4: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.61MiB in 00:00
# 172
# Ezhel - Bul Beni
# [youtube] iurfbuXpqXM: Downloading webpage
# [youtube] iurfbuXpqXM: Downloading android player API JSON
# [info] iurfbuXpqXM: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.93MiB in 00:01
# 173
# Ezhel - Geceler (Official Video) 2018
# [youtube] -x5LnDSctk0: Downloading webpage
# [youtube] -x5LnDSctk0: Downloading android player API JSON
# [info] -x5LnDSctk0: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.36MiB in 00:00
# 174
# Ezhel - Felaket (Official Audio)
# [youtube] 5dJ5ykLNDGY: Downloading webpage
# [youtube] 5dJ5ykLNDGY: Downloading android player API JSON
# [info] 5dJ5ykLNDGY: Downloading 1 format(s): 251
# ...
# [youtube] 2fu8gqFN3XE: Downloading webpage
# [youtube] 2fu8gqFN3XE: Downloading android player API JSON
# [info] 2fu8gqFN3XE: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.81MiB in 00:01
# 522
# Redd - Nefes Bile Almadan (Aşk Tesadüfleri Sever )
# [youtube] NbPsnWUe-y8: Downloading webpage
# [youtube] NbPsnWUe-y8: Downloading android player API JSON
# [info] NbPsnWUe-y8: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.18MiB in 00:01
# 523
# Sena Şener - Dostum Değil Uykular
# [youtube] j4aZAzYCnso: Downloading webpage
# [youtube] j4aZAzYCnso: Downloading android player API JSON
# [info] j4aZAzYCnso: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.67MiB in 00:01
# 524
# Yuksek Sadakat - Doneceksin Diye Soz Ver
# [youtube] 58YMgJIaT8w: Downloading webpage
# [youtube] 58YMgJIaT8w: Downloading android player API JSON
# [info] 58YMgJIaT8w: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.98MiB in 00:01
# 525
# Sebnem Ferah - Yagmurlar
# [youtube] mRV8s7YJpCQ: Downloading webpage
# [youtube] mRV8s7YJpCQ: Downloading android player API JSON
# [info] mRV8s7YJpCQ: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.64MiB in 00:01
# 526
# Sezen Aksu - Kurşuni Renkler  (Lyrics  Şarkı Sözleri)
# [youtube] hmcUQVf_b-M: Downloading webpage
# [youtube] hmcUQVf_b-M: Downloading android player API JSON
# [info] hmcUQVf_b-M: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.59MiB in 00:01
# 527
# Hande Mehan - Sen Beni Güzel Hatırla (Official Audio)
# [youtube] imAwaqV8k50: Downloading webpage
# [youtube] imAwaqV8k50: Downloading android player API JSON
# [info] imAwaqV8k50: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 5.08MiB in 00:00
# 528
# Cem Adrian - Beni Affet Bu Gece (Official Audio)
# [youtube] rbywSJETHJw: Downloading webpage
# [youtube] rbywSJETHJw: Downloading android player API JSON
# [info] rbywSJETHJw: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 2.81MiB in 00:00
# 529
# Perdenin Ardındakiler - Ankarayla Bozuşuruz
# [youtube] FOffDLV9Byg: Downloading webpage
# [youtube] FOffDLV9Byg: Downloading android player API JSON
# [info] FOffDLV9Byg: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.24MiB in 00:00
# 530
# Perdenin Ardındakiler - Beni Kendinden Kurtar
# [youtube] QIzbzyhvklA: Downloading webpage
# [youtube] QIzbzyhvklA: Downloading android player API JSON
# [info] QIzbzyhvklA: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.76MiB in 00:01
# 531
# Derya Uluğ  Sana Çıkıyor Yollar (Lyrics)
# [youtube] MTUsIRYeKIQ: Downloading webpage
# [youtube] MTUsIRYeKIQ: Downloading android player API JSON
# [info] MTUsIRYeKIQ: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 5.07MiB in 00:01
# 532
# Cem Adrian - Mutlu Yıllar
# [youtube] mpohX_R0f2I: Downloading webpage
# [youtube] mpohX_R0f2I: Downloading android player API JSON
# [info] mpohX_R0f2I: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.75MiB in 00:01
# 533
# Aşk Official Video - Gökhan Türkmen Aşk
# [youtube] fTGf_KIgW4Y: Downloading webpage
# [youtube] fTGf_KIgW4Y: Downloading android player API JSON
# [info] fTGf_KIgW4Y: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.59MiB in 00:01
# 534
# Sena Şener - Her An Gidebilirim
# [youtube] sXXPgal-BM0: Downloading webpage
# [youtube] sXXPgal-BM0: Downloading android player API JSON
# [info] sXXPgal-BM0: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.67MiB in 00:01
# 535
# Sertab Erener - Olsun
# [youtube] ik4prAU6r4s: Downloading webpage
# [youtube] ik4prAU6r4s: Downloading android player API JSON
# [info] ik4prAU6r4s: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.06MiB in 00:01
# 536
# Pinhani ft. Kalben - Iyi Degilim Ben (Yollar Bizi Bekler - 2019)
# [youtube] p5QepsqnLwo: Downloading webpage
# [youtube] p5QepsqnLwo: Downloading android player API JSON
# [info] p5QepsqnLwo: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.23MiB in 00:01
# 537
# Alev Alev
# [youtube] BLxfdXR-QB4: Downloading webpage
# [youtube] BLxfdXR-QB4: Downloading android player API JSON
# [info] BLxfdXR-QB4: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.98MiB in 00:01
# 538
# Göksel - Yalnız Kuş (Official Video)
# [youtube] qcb_IUqn3go: Downloading webpage
# [youtube] qcb_IUqn3go: Downloading android player API JSON
# [info] qcb_IUqn3go: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.51MiB in 00:00
# 539
# Sena Sener - Kapkaranlık Her Gunum
# [youtube] brRnhthvnKs: Downloading webpage
# [youtube] brRnhthvnKs: Downloading android player API JSON
# [info] brRnhthvnKs: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.19MiB in 00:00
# 540
# Cem Adrian  Hande Mehan - Sen Benim Sarkılarımsın (Official Audio)
# [youtube] Uvi8b8hHpF4: Downloading webpage
# [youtube] Uvi8b8hHpF4: Downloading android player API JSON
# [info] Uvi8b8hHpF4: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.20MiB in 00:01
# 541
# Yalnızım
# [youtube] FtAlJIooAF8: Downloading webpage
# [youtube] FtAlJIooAF8: Downloading android player API JSON
# [info] FtAlJIooAF8: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.35MiB in 00:01
# 542
# Gökhan Kırdar Yerine Sevemem 1994 (Official Audio) GökhanKırdar YerineSevemem
# [youtube] UooE3twEpEA: Downloading webpage
# [youtube] UooE3twEpEA: Downloading android player API JSON
# [info] UooE3twEpEA: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.75MiB in 00:01
# 543
# Can Ozan - Toprak Yağmura
# [youtube] bvtCGLZcaWs: Downloading webpage
# [youtube] bvtCGLZcaWs: Downloading android player API JSON
# [info] bvtCGLZcaWs: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.49MiB in 00:02
# 544
# Sertab Erener - Karbeyaz
# [youtube] 1YqHB7Yfbzo: Downloading webpage
# [youtube] 1YqHB7Yfbzo: Downloading android player API JSON
# [info] 1YqHB7Yfbzo: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 6.81MiB in 00:02
# 545
# Nilipek. - Gömülür
# [youtube] WBCiQTk5knY: Downloading webpage
# [youtube] WBCiQTk5knY: Downloading android player API JSON
# [info] WBCiQTk5knY: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.52MiB in 00:00
# 546
# Sertab Erener - Bir Çaresi Bulunur
# [youtube] BaRLonlJDOI: Downloading webpage
# [youtube] BaRLonlJDOI: Downloading android player API JSON
# [info] BaRLonlJDOI: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.68MiB in 00:01
# 547
# Teoman - Çoban Yıldızı (Official Video)
# [youtube] aLWKDXkqL5w: Downloading webpage
# [youtube] aLWKDXkqL5w: Downloading android player API JSON
# [info] aLWKDXkqL5w: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.69MiB in 00:00
# 548
# Sertab Erener - Soz Bitti (Album Version)
# [youtube] L8KMDmUQlZo: Downloading webpage
# [youtube] L8KMDmUQlZo: Downloading android player API JSON
# [info] L8KMDmUQlZo: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.75MiB in 00:01
# 549
# Sena Şener - Bak Bana
# [youtube] oXrCX9bgTz8: Downloading webpage
# [youtube] oXrCX9bgTz8: Downloading android player API JSON
# [info] oXrCX9bgTz8: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 7.38MiB in 00:03
# 550
# Cem Adrian - Bana Ne Yaptın (Official Audio)
# [youtube] CKzWhG8whgs: Downloading webpage
# [youtube] CKzWhG8whgs: Downloading android player API JSON
# [info] CKzWhG8whgs: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.91MiB in 00:01
# 551
# Cem Adrian - Biz Senle (Official Audio)
# [youtube] mrRQVEkw-6M: Downloading webpage
# [youtube] mrRQVEkw-6M: Downloading android player API JSON
# [info] mrRQVEkw-6M: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.52MiB in 00:01
# 552
# Sertab Erener - Rüya (Official Audio)
# [youtube] M5axrGmmaSs: Downloading webpage
# [youtube] M5axrGmmaSs: Downloading android player API JSON
# [info] M5axrGmmaSs: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.34MiB in 00:00
# 553
# Onur Can Özcan - Hırka
# [youtube] QmsDsG5hWsg: Downloading webpage
# [youtube] QmsDsG5hWsg: Downloading android player API JSON
# [info] QmsDsG5hWsg: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.67MiB in 00:01
# 554
# Sezen Aksu - Ben Öyle Birini Sevdim Ki (Delibal Soundtrack)
# [youtube] i1QwviZkTdQ: Downloading webpage
# [youtube] i1QwviZkTdQ: Downloading android player API JSON
# [info] i1QwviZkTdQ: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.58MiB in 00:01
# 555
# Cem Adrian - Bu Sarkı Aska Yazıldı (Lyric Video)
# [youtube] MwBlO7NwgYk: Downloading webpage
# [youtube] MwBlO7NwgYk: Downloading android player API JSON
# [info] MwBlO7NwgYk: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.42MiB in 00:01
# 556
# Sertab Erener - Vur Yüreğim - Sertab Erener
# [youtube] OZitHMj25EA: Downloading webpage
# [youtube] OZitHMj25EA: Downloading android player API JSON
# [info] OZitHMj25EA: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.24MiB in 00:01
# 557
# mor ve ötesi - Küçük Sevgilim (Official Video)
# [youtube] oF0NhmAFpDI: Downloading webpage
# [youtube] oF0NhmAFpDI: Downloading android player API JSON
# [info] oF0NhmAFpDI: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.40MiB in 00:00
# 558
# Emre Aydın - Hoşçakal
# [youtube] zDywGq8so-Y: Downloading webpage
# [youtube] zDywGq8so-Y: Downloading android player API JSON
# [info] zDywGq8so-Y: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.60MiB in 00:01
# 559
# Perdenin Ardındakiler - Kendime
# [youtube] tN0tDRCachE: Downloading webpage
# [youtube] tN0tDRCachE: Downloading android player API JSON
# [info] tN0tDRCachE: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.92MiB in 00:01
# 560
# Emre Aydin - Son Defa
# [youtube] Xh2iNOv8Iuw: Downloading webpage
# [youtube] Xh2iNOv8Iuw: Downloading android player API JSON
# [info] Xh2iNOv8Iuw: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.22MiB in 00:00
# 561
# Perdenin Ardındakiler - Kalbinde Birileri Var
# [youtube] jiyTjN_V4gw: Downloading webpage
# [youtube] jiyTjN_V4gw: Downloading android player API JSON
# [info] jiyTjN_V4gw: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.14MiB in 00:00
# 562
# Pinhani - Sen Olmayınca
# [youtube] p-tXWudPdqg: Downloading webpage
# [youtube] p-tXWudPdqg: Downloading android player API JSON
# [info] p-tXWudPdqg: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.41MiB in 00:01
# 563
# Beni Biraz Böyle Hatırla
# [youtube] WdKA9Fg0ddU: Downloading webpage
# [youtube] WdKA9Fg0ddU: Downloading android player API JSON
# [info] WdKA9Fg0ddU: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.85MiB in 00:01
# 564
# Redd - Beni Sevdi Benden Çok
# [youtube] ded2HCHjA6o: Downloading webpage
# [youtube] ded2HCHjA6o: Downloading android player API JSON
# [info] ded2HCHjA6o: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.35MiB in 00:01
# 565
# Cem Adrian  Halil Sezai - Buruk
# [youtube] gdFVBaZ3EXo: Downloading webpage
# [youtube] gdFVBaZ3EXo: Downloading android player API JSON
# [info] gdFVBaZ3EXo: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.98MiB in 00:01
# 566
# Cem Adrian  Mark Eliyahu - KÜL
# [youtube] cwedHo0CT5g: Downloading webpage
# [youtube] cwedHo0CT5g: Downloading android player API JSON
# [info] cwedHo0CT5g: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.22MiB in 00:01
# 567
# Cem Adrian  Ceylan Ertem - Bu Gece Uyut Beni (Official Audio)
# [youtube] KkjS3FVroM0: Downloading webpage
# [youtube] KkjS3FVroM0: Downloading android player API JSON
# [info] KkjS3FVroM0: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 5.78MiB in 00:02
# 568
# Pilli Bebek - Kızım
# [youtube] svgmDXopQwk: Downloading webpage
# [youtube] svgmDXopQwk: Downloading android player API JSON
# [info] svgmDXopQwk: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.91MiB in 00:01
# 569
# Yaralarını Ben Sarayım
# [youtube] w2bflzAq5BI: Downloading webpage
# [youtube] w2bflzAq5BI: Downloading android player API JSON
# [info] w2bflzAq5BI: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.15MiB in 00:00
# 570
# Can Koç - Gökyüzünü Tutamam (Official Lyric Video)
# [youtube] ZOVqeQ_vjYk: Downloading webpage
# [youtube] ZOVqeQ_vjYk: Downloading android player API JSON
# [info] ZOVqeQ_vjYk: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.72MiB in 00:01
# 571
# Nev - Zor
# [youtube] qQ_JEQgD1d8: Downloading webpage
# [youtube] qQ_JEQgD1d8: Downloading android player API JSON
# [info] qQ_JEQgD1d8: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.64MiB in 00:00
# 572
# Cem Adrian - Gül (Official Video)
# [youtube] lzVGkmXangQ: Downloading webpage
# [youtube] lzVGkmXangQ: Downloading android player API JSON
# [info] lzVGkmXangQ: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.63MiB in 00:01
# 573
# Cem Özkan - Dön Bana (Official Video)
# [youtube] Om7k6izmqGE: Downloading webpage
# [youtube] Om7k6izmqGE: Downloading android player API JSON
# [info] Om7k6izmqGE: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.31MiB in 00:01
# 574
# Ufuk Beydemir - HİÇ
# [youtube] 48BrcXVhk_w: Downloading webpage
# [youtube] 48BrcXVhk_w: Downloading android player API JSON
# [info] 48BrcXVhk_w: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 3.05MiB in 00:00
# 575
# Edis - Vay (Her Şey Aşktan Film Müziği)
# [youtube] ODRDJTQEumA: Downloading webpage
# [youtube] ODRDJTQEumA: Downloading android player API JSON
# [info] ODRDJTQEumA: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.07MiB in 00:01
# 576
# emre aydın  Çağan Şengül - Beni Anla
# [youtube] yFxYNNFzZkc: Downloading webpage
# [youtube] yFxYNNFzZkc: Downloading android player API JSON
# [info] yFxYNNFzZkc: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 5.50MiB in 00:02
# 577
# Cem Adrian - Gemiler (Lyric Video)
# [youtube] nV3WxRi3dgE: Downloading webpage
# [youtube] nV3WxRi3dgE: Downloading android player API JSON
# [info] nV3WxRi3dgE: Downloading 1 format(s): 251
# [download] Destination: temp.wav
# [download] 100% of 4.08MiB in 00:01
# 578
# Göksel - Sen Orda Yoksun (Official Video)
# --------------------------------
# It took : 2818.27 seconds to download & get info about 449 songs

# %%
tags
# Out:
# {'(OFFICIAL',
#  'ALBÜM',
#  'DINLE',
#  'GÖKSEL',
#  'GÖKSEL DINLE',
#  'GÖKSEL SON ALBÜM',
#  'GÖKSEL SON ALBÜM DINLE',
#  'GÖKSEL YENI ALBÜM',
#  'GÖKSEL YENI ALBÜM DINLE',
#  'GÖKSEL YENI KLIBI',
#  'GÖKSEL YENI KLIP',
#  'GÖKSEL YENI VIDEO',
#  'GÖKSEL YENI ŞARKI',
#  'GÖKSEL YENI ŞARKISI',
#  'GÖRKSEL',
#  'GÖRKSEL YENI ŞARKI DINLE',
#  'KLIBI',
#  'KLIP',
#  'MÜZIK',
#  'MÜZIK DINLE',
#  'ORDA',
#  'POP',
#  'SEN',
#  'SEN ORDA YOKSUN',
#  'SEN ORDA YOKSUN (OFFICIAL VIDEO)',
#  'SEN ORDA YOKSUN KLIP',
#  'SEN ORDA YOKSUN VIDEO',
#  'SON',
#  'TÜRKÇE',
#  'TÜRKÇE POP',
#  'TÜRKÇE POP DINLE',
#  'VIDEO',
#  'VIDEO)',
#  'YENI',
#  'YOKSUN',
#  'ŞARKI',
#  'ŞARKISI'}
